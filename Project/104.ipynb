# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.104.com.tw/jobs/search/?ro=0&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=16&asc=0&page=1&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1"


headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"}
# 可能是headers 少一個從哪個網站來
response = requests.get(url,headers=headers)
# HERE


print(response.text)

# html = BeautifulSoup(response.text, "html.parser")

# jobs = html.find_all("article", class_="b-block--top-bord")

# for job in jobs:
#     linkbox = job.find("a", class_="js-job-link")
#     joblink = "https:" + linkbox["href"]
#     print(joblink)

#     url2 = f"{joblink}"
#     response2 = requests.get(url2)
#     # print(response2) # <Response [200]>
#     html2 = BeautifulSoup(response2.text, "html.parser")
#     info = html2.find("div", class_="mobile")
#     print(info)
#     break  # 先找一筆就好，免鎖ip
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-hant"><head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <title>最新工作職缺－2023年3月｜104人力銀行</title>
#     <meta name="description" content="2023/3/16－446937 個工作機會｜生管打單人員【將運螺絲工業有限公司】、行政文書人員【申邦環保實業有限公司】、Customer Care Professional | 信用卡會員服務顧問【台灣美國運通國際股份有限公司】。104提供全台最多工作職缺及求職服務，更多最新工作職缺請上104。">
#     <meta property="og:title" content="最新工作職缺－2023年3月｜104人力銀行">
#     <meta property="og:image" content="https://cdn.104.com.tw/static/images/og/company.png">
#     <meta property="og:image:alt" content="找頭鹿找公司｜ 104 人力銀行" />
#     <meta property="og:url" content="https:https://www.104.com.tw/jobs/search/">
#     <meta property="og:type" content="website">
#     <meta property="og:site_name" content="104人力銀行">
#     <meta property="og:description" content="2023/3/16－446937 個工作機會｜生管打單人員【將運螺絲工業有限公司】、行政文書人員【申邦環保實業有限公司】、Customer Care Professional | 信用卡會員服務顧問【台灣美國運通國際股份有限公司】。104提供全台最多工作職缺及求職服務，更多最新工作職缺請上104。">
# ...
